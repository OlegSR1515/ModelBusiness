# %% [markdown]
# <!--<div align="center">Семинар № 2-->
#
# <div align="center"><font color=#4682B4 size=4 face=
#                           "arial black"><em><strong>Семинар № 4</strong></em></font></div>

# %% [markdown]
# <div class="alert alert-block alert-info"><em>
# <b>Задание. </b><br>Опишите процесс «Оформление договора» (с подрядчиком/клиентом)<br>
#     в таблице и с помощью графического способа.
# </em></div>

# %% [markdown]
# |  №    | операция| условие для начала<br> операции|исполнитель,<br> отдел|срок|результат операции|
# |  ---: | :---: | :---: | :---: |:---: |:---: |
# |**`1`**| Создание проекта<br>договора|Заказ клиента|Менеджер|30 минут|Проект договора|
# |**`2`**|Согласование с<br>юридическим отделом|Проект договора<br>для согласования|Юридический<br>отдел|2 часа|Согласованный проект<br> договора
# |**`3`**|Согласование с<br>экономическим отделом|Проект договора<br>для согласования|Экономический<br> отдел|2 часа|Согласованный проект<br> договора
# |**`4`**|Согласование с<br> клиентом|Проект договора<br>для согласования|Менеджер|24 часа|Согласованный проект<br> договора
# |**`5`**|Оформление согласованной<br> редакции договора |Согласованный проект<br> договора|Менеджер|4 часа|Окончательная <br>редакция договора
# |**`6`**|Подписание клиентом|Окончательная<br> редакция договора|Клиент|24 часа|Подписанный<br> договор клиентом
# |**`7`**|Подписание<br> главным бухгалтером|Подписанный договор<br> клиентом|Главный<br> бухгалтер|2 часа|Подписанный договор<br> клиентом и гл.бухгалтером
# |**`8`**|Подписание<br> генеральным директором|Подписанный договор<br> клиентом и гл.бухгалтером|Генеральный<br> директор|24 часа|Подписанный договор<br> (финальная весия)
# |**`9`**|Отправка договора клиенту|Подписанный договор<br> (финальная весия)|Менеджер|2 часа|Подписанный договор<br> получен клиентом

# %% [markdown]
# ***

# %% [markdown]
# <img src="Дом.задание_4.png" width="800" height="150">

# %% [markdown]
# ***
