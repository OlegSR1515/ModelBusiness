# %% [markdown]
# <!--<div align="center">Семинар № 2-->
#
# <div align="center"><font color=#4682B4 size=4 face=
#                           "arial black"><em><strong>Промежуточная аттестация</strong></em></font></div>

# %% [markdown]
# <div class="alert alert-block alert-info"><em>
# <b>Задание. <br>Урок 11. Непрерывный процесс совершенствования.</b><br>
# Собрать в единую презентацию полный проект по оптимизации бизнес-процессов:
#
# 1. Перечислите основные и поддерживающие бизнес-процессы
# 2. Декомпозируйте процессы вашего отдела до 3-5 уровня
# 3. Опишите 1 важный процесс в одной из нотации (BPMN, UML)
# 4. Предложите и приоритезируйте 3 инициативы по оптимизации бизнес-процессов
# 5. Посчитайте экономический эффект от каждой инициативы (по желанию)
# 6. Приоритизируйте инициативы с помощью фреймворка RICE
# 7. Запланируйте проект (этапы, сроки, участники) по внедрению инициатив по оптимизации процессов

# %% [markdown]
# <h2 align='center'> 1.</h2>

# %% [markdown]
# **Основными** или **операционными** бизнес-процессами, называют процессы,<br>
# от которых напрямую зависит прибыль компании.<br>
# Например :
#
#  + Продажа;
#  + Маркетинг;
#  + Производство.
#
# **Вспомогательные** или **поддерживающие** процессы не добавляют ценности продукции<br>
# и являются затратными по своей сути.<br>
# К таким процессам обычно относятся:
#
# - Подготовка кадров;
# - Сервисное обслуживание оборудования;
# - Обеспечение связью;
# - IT – обеспечение;
# - Административно – хозяйственное деятельность.

# %% [markdown]
# ***

# %% [markdown]
# <h2 align='center'> 2.</h2>

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ***

# %% [markdown]
# <h2 align='center'>3.</h2>
# <br>

# %% [markdown]
# <img src="ДЗ_6_1.png" width="1000" height="200">

# %% [markdown]
# ***

# %% [markdown]
# <h2 align='center'>4.</h2>

# %% [markdown]
# ### Этапы по оптимизации бизнес-процессов для решения проблемы предоставления клиентам устаревшей информации по велосипедным турам.
#
# + Определяем возможные бизнес-процессы, приводящие к проблеме;
# + Из скоринг-таблицы выделяем бизнес-процесс с наибольшими баллами;
# + Даём рекомендации для проверки выявленного бизнес процесса для устранения проблеиы.
#
# |  №| процесс| возможность<br> снижения<br> издержек|источник<br>жалоб|возможность<br>улучшения|простота<br>улучшения|источник<br>недовольства<br>сотрудников|трудозатраты|ИТОГО|
# |---: | :---: | :---: | :---: |:---: |:---: |:---: |:---:|:---:|
# |<font color='#FF8C00' size=3 face='wide latin'>1</font>|<font color='#FF8C00' size=3 face='wide latin'>Своевременное обновление<br> баз данных туров</font>    |<font color='#FF8C00' size=3 face=' latin'>**4**</font>|<font color='#FF8C00' size=3 face='latin'>**5**</font>|<font color='#FF8C00' size=3 face='latin'>**5**</font>|<font color='#FF8C00' size=3 face='latin'>**2**</font>|<font color='#FF8C00' size=3 face='latin'>**4**</font>|<font color='#FF8C00' size=3 face='latin'>**4**</font>|<font color='#FF8C00' size=4 face='latin'>**24**</font>|
# |**`2`**|Мониторинг базы<br> данных клиентов               |3|3|3|4|2|2|**17**|
# |**`3`**|Периодичность рассылки<br> новых данных           |5|4|3|3|2|3|**20**|
# |**`4`**|Написание инструкций по<br> работе с базами данных|2|2|4|5|3|3|**19**|

# %% [markdown]
# В результате скоринг-аналитики даем рекомендации прежде всего проверить процесс<br>
# <font color='#FF00FF' size=4 face='wide latin'><b>- своевременного обновления баз данных туров</b></font>.

# %% [markdown]
# ***

# %% [markdown]
# <h2 align='center'>5.</h2>

# %% [markdown]
# ### Расчёт стоимости и ключевых показателей эффективности процесса<br> «Изготовление заглушки и доставка товара заказчику»<br>по всем типам показателей.
#
#  ### Трудозатраты

# %% [markdown]
# <img src="ДЗ_7_1.png" width="800" height="1200">

# %% [markdown]
# ### Материальные затраты

# %% [markdown]
# <img src="ДЗ_7_23.png" width="330" height="200">

# %% [markdown]
# ### Показатели качества

# %% [markdown]
# <img src="ДЗ_7_31.png" width="300" height="200">

# %% [markdown]
# ***

# %% [markdown]
# <h2 align='center'>6.</h2>

# %% [markdown]
# ### Пример приоритезации инициатив при помощи фреймворка RICE на примере решения проблемы снижения производительности и выгорания сотрудников некой компании.

# %% [markdown]
# В результате проведенных опросов были выявлены последствия, а не причины.<br>
# Стало только понятней, что причины снижения бизнес-результатов могут, но *не обязаны*, <br>
# лежать в организации труда и выявили плохое состояние рабочей атмосферы среди сотрудников.<br>
# Однако, абсолютно не ясно, какие измения в работе сотрудников привели к текущей ситуации.<br>
# Пока, бесспорно только одно: **сотрудники работают без прежнего энтузиазма, работа стала втягость,<br> собачатся друг с другом и эмоционально увольняются, "хлопнув дверью"**.<br>
# Типо **_"Да пошли вы все куда подальше"_**.<br>
#
# Ситуация близка к катастрофе и развалу компании.<br>
# **Требуются срочные меры!**<br>
# Но неизвестно какие конкретно.
#
# Поэтому, я бы, прежде всего, провел личные встречи с сотрудниками,<br>
# на которых максимально детализировал бы вопросы по возможным причинам проблем,<br>
# таким, как:
# + поставленные задачи слишком просты и не соответсвуют квалификации сотрудника;
# + сроки выполнения работы слишком маленькие;
# + сложность задачи превосходит квалификацию сотрудника;
# + неправильная организация рабочего времени(нет времени на отдых);
# + слишком большое количество задач для одного сотрудника;
# + тема задачи не вызывает интерес у сотрудника;
# + неправильная организация рабочего места (нет возможности сосредоточиться);
# + заработная плата не соответствует уровню задач;
# + нет системы премий или просто поощрений;
# + сотрудники плохо знают друг друга и сложно коммуницируют;
# + сотрудники не понимают главную задачу компании и важность их вклада в общий результат;
# + техническое состояние предоставленного компанией оборудования слишком старое<br>
# и не позволчет качественно выполнить работу;
# + и, возможно, ещё что…

# %% [markdown]
# Но, так как в задании уже сейчас хотят приоритезацию по RICE, что ж.<br>
# Но инициатив у меня будет шесть.<br>
# **Max-5** баллов, максимальный охват или, например, влияние… **Мin-1** балл.

# %% [markdown]
# |  №  | ACTION| REACH |IMPACT |CONFIDENCE|TOTAL|
# |---: | :---: | :---: | :---: |:---:     |:---:|
# |<font color='#FF0000' size=3 face='wide latin'>1</font>|<font color='#FF0000' size=3 face='wide latin'>Личные беседы с сотрудниками</font>    |<font color='#FF0000' size=3 face=' latin'>**5**</font>|<font color='#FF0000' size=3 face='latin'>**5**</font>|<font color='#FF0000' size=3 face='latin'>**5**</font>|<font color='#FF0000' size=3 face='latin'>**15**</font>|
# |<font color='#9ACD32' size=2 face='wide latin'>2</font>|<font color='#9ACD32' size=3 face='wide latin'>Общее собрание сотрудников</font>    |<font color='#9ACD32' size=3 face=' latin'>**5**</font>|<font color='#9ACD32' size=3 face='latin'>**5**</font>|<font color='#9ACD32' size=3 face='latin'>**4**</font>|<font color='#9ACD32' size=3 face='latin'>**14**</font>|
# |<font color='#9ACD32' size=2 face='wide latin'>3</font>|<font color='#9ACD32' size=3 face='wide latin'>Вечеринка<br>в неформальной обстановке</font>    |<font color='#9ACD32' size=3 face=' latin'>**5**</font>|<font color='#9ACD32' size=3 face='latin'>**5**</font>|<font color='#9ACD32' size=3 face='latin'>**4**</font>|<font color='#9ACD32' size=3 face='latin'>**14**</font>|
# |**`4`**|Мониторинг рабочего времени               |4|3|2|**9**|
# |**`5`**|Проверка квалификации сотрудника          |5|4|3|**12**|
# |**`6`**|Проверка условий труда на<br>соответствие нормам с лидерами отрасли|5|4|2|**11**|

# %% [markdown]
# <div class="alert alert-block alert-success"><em>
#     <b>Рекомендации:</b><br>Победили <b>1.Личные беседы с сотрудниками</b>,<br>
#     но чтобы не терять время проводим инициативы с номерами <b>2.</b> и <b>3.</b>,<br>
#     также имеющими высокие баллы по RICE.<br>
#
# <b><font color='#0000FF' size=4 face='wide latin'>Возможно, мы уже сможем начать исправлять ситуацию, до тех пор пока получим конкретику.</font></b>.
# </em></div>

# %% [markdown]
# ***

# %% [markdown]
# <h2 align='center'>7.</h2>

# %% [markdown]
# ### Примерный план проекта для создания мобильной версии сайта.

# %% [markdown]
# <h2 align='center'> SMART-цель проекта</h2>
#
# + **S**$~~~$Specific$~~~~~~~~~$***точность цели***$~~~~~~~$Разработка мобильной версии сайта<br>
# + **M**$~~~$Measurable$~~~$***измеримость***$~~~~~~~~~~$Как минимум 50% текщих пользователей сайта перешли<br>$~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~$ на его мобильную версию
# + **A**$~~~$Achiveable$~~~~~$***достижимость***$~~~~~~$Наличие ресурсов и специалистов
# + **R**$~~~$Relevant$~~~~~~~~$***актуальность***$~~~~~~~~$Использавание мобильной версии сайта удовлетворит<br>
# $~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~$просьбы клиентов о возможности мобильных заказов,<br>
# $~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~$а, следовательно, увеличит посещаемость и выручку<br>
# + **T**$~~~$Time bound$~~~~~$***временные рамки***$~~$Сроки реализации - 2 месяца

# %% [markdown]
# <h2 align='center'> Состав команды проекта</h2>
#
# + Проджект Менеджер
# + Разработчики
# + Тестировщик
# + Аналитик
# + Рекламный менеджер

# %% [markdown]
# <h2 align='center'>План-график проекта</h2>

# %% [markdown]
# <img src="ДЗ_10_1.png" width="800" height="1200">

# %% [markdown]
# ***
