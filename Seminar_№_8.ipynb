# %% [markdown]
# <!--<div align="center">Семинар № 2-->
#
# <div align="center"><font color=#4682B4 size=4 face=
#                           "arial black"><em><strong>Семинар № 8</strong></em></font></div>

# %% [markdown]
# <div class="alert alert-block alert-info"><em>
# <b>Задание. <br>Урок 8. Формирование предварительных гипотез по улучшению процессов.</b><br>
# Недавно бизнес-аналитик устроился на руководящую должность в компании AA<br>
# по организации туров на велосипедах. Девять месяцев назад компания начала предоставлять новую услугу:<br>
#     сотрудники начали использовать электронную почту для уведомления клиентов о новых турах<br>
#     и предлагали скачать сведения о текущих планах туров и подробные инструкции.<br>
#
# Сначала клиенты были довольны новой услугой. Однако в последнее время многие начали жаловаться<br>
# на получение устаревшей туристической информации.<br>
# Аналитик понимает, что проблема заключается в процессе обновления информации<br>
# и редактирования списка рассылки.<br>
#     Но он не знал, как решить эту проблему.<br>
# Ответить на вопросы:
# - Что бы сделали вы?
# - По каким критериям, кроме указанных в таблице, могут быть ранжированы<br>
#     предполагаемые к улучшению процессы?

# %% [markdown]
# + Определяем возможные бизнес-процессы, приводящие к проблеме;
# + Из скоринг-таблицы выделяем бизнес-процесс с наибольшими баллами;
# + Даём рекомендации для проверки выявленного бизнес процесса для устранения проблеиы.
#
# |  №| процесс| возможность<br> снижения<br> издержек|источник<br>жалоб|возможность<br>улучшения|простота<br>улучшения|источник<br>недовольства<br>сотрудников|трудозатраты|ИТОГО|
# |---: | :---: | :---: | :---: |:---: |:---: |:---: |:---:|:---:|
# |<font color='#FF8C00' size=3 face='wide latin'>1</font>|<font color='#FF8C00' size=3 face='wide latin'>Своевременное обновление<br> баз данных туров</font>    |<font color='#FF8C00' size=3 face=' latin'>**4**</font>|<font color='#FF8C00' size=3 face='latin'>**5**</font>|<font color='#FF8C00' size=3 face='latin'>**5**</font>|<font color='#FF8C00' size=3 face='latin'>**2**</font>|<font color='#FF8C00' size=3 face='latin'>**4**</font>|<font color='#FF8C00' size=3 face='latin'>**4**</font>|<font color='#FF8C00' size=4 face='latin'>**24**</font>|
# |**`2`**|Мониторинг базы<br> данных клиентов               |3|3|3|4|2|2|**17**|
# |**`3`**|Периодичность рассылки<br> новых данных           |5|4|3|3|2|3|**20**|
# |**`4`**|Написание инструкций по<br> работе с базами данных|2|2|4|5|3|3|**19**|

# %% [markdown]
# В результате скоринг-аналитики даем рекомендации прежде всего проверить процесс<br>
# <font color='#FF00FF' size=4 face='wide latin'>***своевременного обновление баз данных туров***</font>.

# %% [markdown]
# ***
